# %%
import os
import librosa
import math
import json

data = {
    "mapping": [],
    "mfcc": [],
    "labels": []
}
SAMPLE_RATE = 22050
DURATION = 30
SAMPLE_PER_TRACK = SAMPLE_RATE * DURATION
num_segments = 10
num_samples_per_segment = int(SAMPLE_PER_TRACK / num_segments)
n_fft = 2048
hop_length = 512
n_mfcc = 13
expected_num_mfcc_vectors_per_segment = math.ceil(num_samples_per_segment / hop_length)

dataset_path = "AudioData/genres_original"
json_path = "data_10.json"
for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):
    if dirpath is not dataset_path:
        dirpath_components = dirpath.split("\\")
        semantic_label = dirpath_components[-1]
        data["mapping"].append(semantic_label)
        print("\nProcessing {}".format(semantic_label))

        for f in filenames:
            # Load audio files
            file_path = os.path.join(dirpath, f)
            signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)

            # process segments extracting mfcc and storing data
            for s in range(num_segments):
                start_sample = num_samples_per_segment * s
                finish_sample = start_sample + num_samples_per_segment

                mfcc = librosa.feature.mfcc(signal[start_sample:finish_sample],
                                            sr=sr,
                                            n_fft=n_fft,
                                            n_mfcc=n_mfcc,
                                            hop_length=hop_length)
                mfcc = mfcc.T
                # store mfcc for segment if it has the expected length
                if len(mfcc) == expected_num_mfcc_vectors_per_segment:
                    data["mfcc"].append(mfcc.tolist())
                    data["labels"].append(i - 1)
                    print("{}, segment:{}".format(file_path, s + 1))

with open(json_path, "w") as fp:
    json.dump(data, fp, indent=4)
# Out:
# Processing blues
# AudioData/genres_reduced\blues\blues.00001.wav, segment:1
# AudioData/genres_reduced\blues\blues.00001.wav, segment:2
# AudioData/genres_reduced\blues\blues.00001.wav, segment:3
# AudioData/genres_reduced\blues\blues.00001.wav, segment:4
# AudioData/genres_reduced\blues\blues.00001.wav, segment:5
# AudioData/genres_reduced\blues\blues.00001.wav, segment:6
# AudioData/genres_reduced\blues\blues.00001.wav, segment:7
# AudioData/genres_reduced\blues\blues.00001.wav, segment:8
# AudioData/genres_reduced\blues\blues.00001.wav, segment:9
# AudioData/genres_reduced\blues\blues.00001.wav, segment:10
#
# Processing classical
# AudioData/genres_reduced\classical\classical.00000.wav, segment:1
# AudioData/genres_reduced\classical\classical.00000.wav, segment:2
# AudioData/genres_reduced\classical\classical.00000.wav, segment:3
# AudioData/genres_reduced\classical\classical.00000.wav, segment:4
# AudioData/genres_reduced\classical\classical.00000.wav, segment:5
# AudioData/genres_reduced\classical\classical.00000.wav, segment:6
# AudioData/genres_reduced\classical\classical.00000.wav, segment:7
# AudioData/genres_reduced\classical\classical.00000.wav, segment:8
# AudioData/genres_reduced\classical\classical.00000.wav, segment:9
# AudioData/genres_reduced\classical\classical.00000.wav, segment:10
#
# Processing country
# AudioData/genres_reduced\country\country.00003.wav, segment:1
# AudioData/genres_reduced\country\country.00003.wav, segment:2
# AudioData/genres_reduced\country\country.00003.wav, segment:3
# AudioData/genres_reduced\country\country.00003.wav, segment:4
# AudioData/genres_reduced\country\country.00003.wav, segment:5
# AudioData/genres_reduced\country\country.00003.wav, segment:6
# AudioData/genres_reduced\country\country.00003.wav, segment:7
# AudioData/genres_reduced\country\country.00003.wav, segment:8
# AudioData/genres_reduced\country\country.00003.wav, segment:9
# AudioData/genres_reduced\country\country.00003.wav, segment:10
#
# Processing disco
# AudioData/genres_reduced\disco\disco.00004.wav, segment:1
# AudioData/genres_reduced\disco\disco.00004.wav, segment:2
# AudioData/genres_reduced\disco\disco.00004.wav, segment:3
# AudioData/genres_reduced\disco\disco.00004.wav, segment:4
# AudioData/genres_reduced\disco\disco.00004.wav, segment:5
# AudioData/genres_reduced\disco\disco.00004.wav, segment:6
# AudioData/genres_reduced\disco\disco.00004.wav, segment:7
# AudioData/genres_reduced\disco\disco.00004.wav, segment:8
# AudioData/genres_reduced\disco\disco.00004.wav, segment:9
# AudioData/genres_reduced\disco\disco.00004.wav, segment:10
#
# Processing hiphop
# AudioData/genres_reduced\hiphop\hiphop.00005.wav, segment:1
# AudioData/genres_reduced\hiphop\hiphop.00005.wav, segment:2
# AudioData/genres_reduced\hiphop\hiphop.00005.wav, segment:3
# AudioData/genres_reduced\hiphop\hiphop.00005.wav, segment:4
# AudioData/genres_reduced\hiphop\hiphop.00005.wav, segment:5
# AudioData/genres_reduced\hiphop\hiphop.00005.wav, segment:6
# AudioData/genres_reduced\hiphop\hiphop.00005.wav, segment:7
# AudioData/genres_reduced\hiphop\hiphop.00005.wav, segment:8
# AudioData/genres_reduced\hiphop\hiphop.00005.wav, segment:9
# AudioData/genres_reduced\hiphop\hiphop.00005.wav, segment:10
#
# Processing jazz
# AudioData/genres_reduced\jazz\jazz.00006.wav, segment:1
# AudioData/genres_reduced\jazz\jazz.00006.wav, segment:2
# AudioData/genres_reduced\jazz\jazz.00006.wav, segment:3
# AudioData/genres_reduced\jazz\jazz.00006.wav, segment:4
# AudioData/genres_reduced\jazz\jazz.00006.wav, segment:5
# AudioData/genres_reduced\jazz\jazz.00006.wav, segment:6
# AudioData/genres_reduced\jazz\jazz.00006.wav, segment:7
# AudioData/genres_reduced\jazz\jazz.00006.wav, segment:8
# AudioData/genres_reduced\jazz\jazz.00006.wav, segment:9
# AudioData/genres_reduced\jazz\jazz.00006.wav, segment:10
#
# Processing metal
# AudioData/genres_reduced\metal\metal.00007.wav, segment:1
# AudioData/genres_reduced\metal\metal.00007.wav, segment:2
# AudioData/genres_reduced\metal\metal.00007.wav, segment:3
# AudioData/genres_reduced\metal\metal.00007.wav, segment:4
# AudioData/genres_reduced\metal\metal.00007.wav, segment:5
# AudioData/genres_reduced\metal\metal.00007.wav, segment:6
# AudioData/genres_reduced\metal\metal.00007.wav, segment:7
# AudioData/genres_reduced\metal\metal.00007.wav, segment:8
# AudioData/genres_reduced\metal\metal.00007.wav, segment:9
# AudioData/genres_reduced\metal\metal.00007.wav, segment:10
#
# Processing pop
# AudioData/genres_reduced\pop\pop.00009.wav, segment:1
# AudioData/genres_reduced\pop\pop.00009.wav, segment:2
# AudioData/genres_reduced\pop\pop.00009.wav, segment:3
# AudioData/genres_reduced\pop\pop.00009.wav, segment:4
# AudioData/genres_reduced\pop\pop.00009.wav, segment:5
# AudioData/genres_reduced\pop\pop.00009.wav, segment:6
# AudioData/genres_reduced\pop\pop.00009.wav, segment:7
# AudioData/genres_reduced\pop\pop.00009.wav, segment:8
# AudioData/genres_reduced\pop\pop.00009.wav, segment:9
# AudioData/genres_reduced\pop\pop.00009.wav, segment:10
#
# Processing reggae
# AudioData/genres_reduced\reggae\reggae.00007.wav, segment:1
# AudioData/genres_reduced\reggae\reggae.00007.wav, segment:2
# AudioData/genres_reduced\reggae\reggae.00007.wav, segment:3
# AudioData/genres_reduced\reggae\reggae.00007.wav, segment:4
# AudioData/genres_reduced\reggae\reggae.00007.wav, segment:5
# AudioData/genres_reduced\reggae\reggae.00007.wav, segment:6
# AudioData/genres_reduced\reggae\reggae.00007.wav, segment:7
# AudioData/genres_reduced\reggae\reggae.00007.wav, segment:8
# AudioData/genres_reduced\reggae\reggae.00007.wav, segment:9
# AudioData/genres_reduced\reggae\reggae.00007.wav, segment:10
#
# Processing rock
# AudioData/genres_reduced\rock\rock.00008.wav, segment:1
# AudioData/genres_reduced\rock\rock.00008.wav, segment:2
# AudioData/genres_reduced\rock\rock.00008.wav, segment:3
# AudioData/genres_reduced\rock\rock.00008.wav, segment:4
# AudioData/genres_reduced\rock\rock.00008.wav, segment:5
# AudioData/genres_reduced\rock\rock.00008.wav, segment:6
# AudioData/genres_reduced\rock\rock.00008.wav, segment:7
# AudioData/genres_reduced\rock\rock.00008.wav, segment:8
# AudioData/genres_reduced\rock\rock.00008.wav, segment:9
# AudioData/genres_reduced\rock\rock.00008.wav, segment:10
